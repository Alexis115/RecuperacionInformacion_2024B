# %% [markdown]
# # Examen B1
#  Alexis Vera

# %% [markdown]
# ### Instalacion de librerias

# %%
pip install nltk scikit-learn
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
pip install nltk scikit-learn pandas
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.9.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.6)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# ### Importarcion de librerias y recursos nltk

# %%
#Importar librerias
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import defaultdict
import json
from nltk.stem import PorterStemmer, WordNetLemmatizer

#Descargar recursos nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# ###Carga del corpus

# %%
#Cargar el archivo CSV del corpus Rotten Tomatoes
corpus_path = 'rotten_tomatoes_critic_reviews.csv'
df = pd.read_csv(corpus_path)

#Verificar las primeras filas del DataFrame
print(df.head())
# Out:
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255    Louise Keller       False           Urban Cinefile
# 2            m/0814255              NaN       False      FILMINK (Australia)
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# 3  Whether audiences will get behind The Lightnin...
# 4  What's really lacking in The Lightning Thief i...

# %% [markdown]
# ##1.- Preprocesamiento de Datos

# %% [markdown]
# ###Funciones de limpieza

# %%
def preprocess_text(text):
    #Herramientas de stemming
    stemmer = PorterStemmer()

    #Convertir a minúsculas
    text = text.lower()
    #Eliminar caracteres especiales y números
    text = re.sub(r'[^a-z\s]', '', text)
    #Tokenización
    tokens = word_tokenize(text)
    #Eliminar stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    #Aplicar stemming
    stemmed_tokens = [stemmer.stem(word) for word in tokens]

    return stemmed_tokens

# %% [markdown]
# ### Aplicar preprocesamiento

# %%
#Seleccionar la columna de objetivo "review_content"
text_column = "review_content"
if text_column not in df.columns:
    raise ValueError(f"La columna '{text_column}' no se encontró. Verifica las columnas disponibles: {df.columns}")

#Aplicar preprocesamiento
df['tokens'] = df[text_column].astype(str).apply(preprocess_text)

#Visualizar texto original y texto preprocesado (primeras filas)
print("Texto original y preprocesado:")
for i in range(5):
    print(f"Original: {df[text_column].iloc[i]}")
    print(f"Preprocesado: {df['tokens'].iloc[i]}")
    print("-" * 50)
# Out:
# Texto original y preprocesado:
# Original: A fantasy adventure that fuses Greek mythology to contemporary American places and values. Anyone around 15 (give or take a couple of years) will thrill to the visual spectacle
# Preprocesado: ['fantasi', 'adventur', 'fuse', 'greek', 'mytholog', 'contemporari', 'american', 'place', 'valu', 'anyon', 'around', 'give', 'take', 'coupl', 'year', 'thrill', 'visual', 'spectacl']
# --------------------------------------------------
# Original: Uma Thurman as Medusa, the gorgon with a coiffure of writhing snakes and stone-inducing hypnotic gaze is one of the highlights of this bewitching fantasy
# Preprocesado: ['uma', 'thurman', 'medusa', 'gorgon', 'coiffur', 'writh', 'snake', 'stoneinduc', 'hypnot', 'gaze', 'one', 'highlight', 'bewitch', 'fantasi']
# --------------------------------------------------
# Original: With a top-notch cast and dazzling special effects, this will tide the teens over until the next Harry Potter instalment.
# Preprocesado: ['topnotch', 'cast', 'dazzl', 'special', 'effect', 'tide', 'teen', 'next', 'harri', 'potter', 'instal']
# --------------------------------------------------
# Original: Whether audiences will get behind The Lightning Thief is hard to predict. Overall, it's an entertaining introduction to a promising new world -- but will the consuming shadow of Potter be too big to break free of?
# Preprocesado: ['whether', 'audienc', 'get', 'behind', 'lightn', 'thief', 'hard', 'predict', 'overal', 'entertain', 'introduct', 'promis', 'new', 'world', 'consum', 'shadow', 'potter', 'big', 'break', 'free']
# --------------------------------------------------
# Original: What's really lacking in The Lightning Thief is a genuine sense of wonder, the same thing that brings viewers back to Hogwarts over and over again.
# Preprocesado: ['what', 'realli', 'lack', 'lightn', 'thief', 'genuin', 'sens', 'wonder', 'thing', 'bring', 'viewer', 'back', 'hogwart']
# --------------------------------------------------

# %%
#Crear índice invertido
inverted_index = defaultdict(list)

for idx, tokens in enumerate(df['tokens']):
    for token in tokens:
        inverted_index[token].append(idx)

#Guardar índice invertido como archivo JSON
with open("inverted_index.json", "w") as f:
    json.dump(inverted_index, f)

print("Índice invertido creado y guardado como 'inverted_index.json'")
# Out:
# Índice invertido creado y guardado como 'inverted_index.json'

# %% [markdown]
# ## 2.- Sistema de Recuperacion

# %%
#Función de búsqueda en el índice invertido
def search_inverted_index(query, inverted_index, df):
    # Preprocesar la consulta
    query_tokens = preprocess_text(query)
    print(f"Términos de búsqueda (preprocesados): {query_tokens}")

    #Recuperar índices de documentos que contienen los términos
    matching_docs = set()
    for token in query_tokens:
        if token in inverted_index:
            matching_docs.update(inverted_index[token])

    #Mostrar documentos encontrados
    if matching_docs:
        print(f"Se encontraron {len(matching_docs)} documentos que coinciden:")
        for doc_id in matching_docs:
            print(f"Documento {doc_id}: {df[text_column].iloc[doc_id]}")
            print("-" * 50)
    else:
        print("No se encontraron documentos para la consulta.")

#Cargar índice invertido generado previamente
with open("inverted_index.json", "r") as f:
    inverted_index = json.load(f)

# %% [markdown]
# ## 3.- Simulacion de Consulta

# %%
#Consulta de ejemplo
query = input("Introduce tu consulta: ")

#Realizar búsqueda
search_inverted_index(query, inverted_index, df)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# Documento 779795: A handsomely-mounted, muscular, red-blooded Old West adventure ... One of the most stunning films to look at in recent years.
# --------------------------------------------------
# Documento 878103: A feast for the eyes and a thrillingly brazen transposition of the high-tech on the old-fashioned, fueled by a dose of what-if historical fantasy.
# --------------------------------------------------
# Documento 124439: A poorly written and disappointingly animated adventure that may keep the wee'uns happy for a while but will leave the adults snoozing.
# --------------------------------------------------
# Documento 517655: [Gibson and Glover] make a great team, and some of their early adventures are exciting. But the film runs out of gas as it turns into an extended chase sequence.
# --------------------------------------------------
# Documento 157211: As a noir-tinged Western hybrid, the film is a classic character study, morality play, and adventurous mystery.
# --------------------------------------------------
# Documento 1041948: Time Bandits remains Fantasy 101, and a must-see for people who enjoy this kind of fare.
# --------------------------------------------------
# Documento 1041949: A smart and imaginative fantasy with appeal for the whole family is always cause for celebration...Time Bandits rivals Roald Dahl in its surrealism and satire. [Blu-ray]
# --------------------------------------------------
# Documento 1041950: one of the greatest of children's fantasy movies
# --------------------------------------------------
# Documento 517661: An enduring buddy film, brilliantly combining drama, comedy, adventure, bloodshed, machine gun showdowns in the middle of busy highways, and excessive property destruction.
# --------------------------------------------------
# Documento 1041952: Fun fantasy has a bit of bite.
# --------------------------------------------------
# Documento 648737: With the freedom of animation comes a more effective blurring of fantasy and reality.
# --------------------------------------------------
# Documento 878113: Visually, the movie is a gearhead's fever dream, a mesmerizing fantasy rooted in the industrial revolution, combining traditional animation and computer effects.
# --------------------------------------------------
# Documento 976419: Sheds light on the generational breach and the infamous glass ceiling for women in the workplace in a moving and entertaining way, creating the fantasy that the ceiling is gone when it is really just moved to another place. [Full review in Spanish]
# --------------------------------------------------
# Documento 124452: Alpha and Omega is a fun filled animated comedy adventure.
# --------------------------------------------------
# Documento 910885: The offbeat beauty of Almodovar's script lies in its seductive combination of grieving, sensuality, fantasy and passion. Almodovar is incapable of creating dull characters...
# --------------------------------------------------
# Documento 222758: Stuns me with its scathing commentary on what is happening in the real world today, wrapped up in what is some of the most delicious, most comic-booky fantasy ever.
# --------------------------------------------------
# Documento 878114: This refreshing and enjoyable alternate history anime film packs quite a lot of action and adventure in one film.
# --------------------------------------------------
# Documento 1009184: Iñárritu captured The Revenant in the wilds of Canada, Argentina, and the United States, using a blend of raw footage and clever computer-generated effects to create a story of survival and adventure that would curdle Jack London's blood.
# --------------------------------------------------
# Documento 1041957: As an adventure tale to enjoy with your kids, you could do much worse than Time Bandits - you just can't expect the depth of Gilliam's more adult works.
# --------------------------------------------------
# Documento 1041960: It's a strange and weird and wonderful mix of boy's own adventure, Python-esque humor, and grim irony, all wrapped in tall tales, ancient myths, and historical figures.
# --------------------------------------------------
# Documento 1041964: Many of the exploits are lightly engaging, but never full of the tension and excitement of more polished adventure films.
# --------------------------------------------------
# Documento 923517: There simply isn't a whole lot of excitement being generated in this lackluster family adventure, though it tries oh so very hard.
# --------------------------------------------------
# Documento 878129: An exciting adventure film with handsome, state-of-the-art animation.
# --------------------------------------------------
# Documento 222771: The Winter Soldier offers plenty for franchise fanatics to chew on, but a half-baked genre switch and increasingly daft 'political' themes make Cap's transitional adventure a minor Marvel at best.
# --------------------------------------------------
# Documento 1074739: 2015's Vacation may not launch a new series of Griswold adventures, but it's a worthy addition to the existing franchise.
# --------------------------------------------------
# Documento 878137: The end credits play over a series of still drawings of Ray and the steamball's further adventures and EVERY SINGLE ONE of them looks more interesting than the movie.
# --------------------------------------------------
# Documento 1107514: It's 'City Slickers' on bikes, probably someone's idea of a 40 year old guy's ultimate fantasy movie.
# --------------------------------------------------
# Documento 878139: Visually, the movie is a gearhead's fever dream, a mesmerizing fantasy rooted in the industrial revolution, combining traditional animation and computer effects.
# --------------------------------------------------
# Documento 878140: This refreshing and enjoyable alternate history anime film packs quite a lot of action and adventure in one film.
# --------------------------------------------------
# Documento 976445: This earnest, effusive haut-bourgeois fantasy, by the writer and director Nancy Meyers, runs roughshod over rational skepticism with the force of her life experience.
# --------------------------------------------------
# Documento 255557: Doesn't operate on a level of logic, being the fantasy that it is, but the enthusiasm of its star and the color dynamics of its lush parade of fashion makes it a solid must see for the teenage girl crowd.
# --------------------------------------------------
# Documento 812614: A ridiculous and just plain goofy romantic fantasy that's as flimsy as a slice of bologna.
# --------------------------------------------------
# Documento 517701: Director Richard Donner accents humour rather than explosive action and the result is an oddly toned, cartoon-like adventure with the comedy elements making the nasty violence seem even more gratuitous.
# --------------------------------------------------
# Documento 648776: Perfect Blue's success lies in the twisted, self-referential storyline that intercuts reality with fantasy so fluidly that viewers inevitably take on Mima's shattered point of view, unable to distinguish the truth until the stunning conclusion.
# --------------------------------------------------
# Documento 878155: An exciting adventure film with handsome, state-of-the-art animation.
# --------------------------------------------------
# Documento 1009229: An eerie, elemental and exhausting epic adventure, making 'Deliverance' look like a walk in the park.
# --------------------------------------------------
# Documento 1009233: A relentlessly-gruesome, gritty and grim adventure reminiscent of how the West was won.
# --------------------------------------------------
# Documento 878163: The end credits play over a series of still drawings of Ray and the steamball's further adventures and EVERY SINGLE ONE of them looks more interesting than the movie.
# --------------------------------------------------
# Documento 812628: A ridiculous and just plain goofy romantic fantasy that's as flimsy as a slice of bologna.
# --------------------------------------------------
# Documento 976469: Those of us who were never cool young guys live with an enduring hope: that someday we'll be cool old guys. It's a fantasy embodied in the flesh - specifically, in the gloriously creased, proudly aging flesh of 72-year-old Robert De Niro
# --------------------------------------------------
# Documento 419417: Adventures, quirkiness, mystery, violence and valuable life lessons are just the things I want youngsters to be reading and Holes is just the kind of movie I want made based on those readings.
# --------------------------------------------------
# Documento 452191: A thoroughly pedestrian adventure that might have been better titled Hell is Lots and Lots of Other People.
# --------------------------------------------------
# Documento 878180: When the "steam castle" morphs into a Spielbergian mother ship, I knew that Otomo's overheated fantasy had, yes, run out of steam.
# --------------------------------------------------
# Documento 222822: A much-improved second outing with a few familiar faces along in his adventure.
# --------------------------------------------------
# Documento 157290: A densely layered, darkly funny look at the lies people tell themselves and others in order to make their fantasies come true.
# --------------------------------------------------
# Documento 878186: When the "steam castle" morphs into a Spielbergian mother ship, I knew that Otomo's overheated fantasy had, yes, run out of steam.
# --------------------------------------------------
# Documento 419436: Older kids, fans of the book and parents who remember the fun of reading dark stories under the covers should be happily engrossed in this adventure.
# --------------------------------------------------
# Documento 452203: The jury's still out on whether or not Langdon will return for another cinematic adventure, but if he does, perhaps it's time to let "Inferno" mark the end of Hanks and Howard's involvement, and let somebody else light a new spark with the franchise.
# --------------------------------------------------
# Documento 419440: The target audience may be satisfied that the book is being respected, and the adventures of Caveman and Zero have a rootable, Hardy Boys interest.
# --------------------------------------------------
# Documento 1009267: It's a grand adventure that delivers on its tale of survival and revenge, and though it might be a little too intense for some, it's ultimately well-worth the two and a half hours to experience one of the most breathtaking films of the year.
# --------------------------------------------------
# Documento 255608: A string of unrelated scenes about the high-school musical ... the band's final concert, some random moments in which some standard-issue popular girls are mean to Lola, and Lola's active fantasy life.
# --------------------------------------------------
# Documento 452222: If you thought Ron Howard's first two adventures based on Dan Brown's best-selling Robert Langdon novels came off moderately stagy and cumbersome, "Inferno" feels like a bad acid trip through a globe-trotting James Bond movie.
# --------------------------------------------------
# Documento 222848: A rousing adventure that will make devoted Captain America fans swoon while also pleasing those who met him only in the first film, but also touches on some hot-button contemporary issues.
# --------------------------------------------------
# Documento 714372: A potentially commercial audience-pleaser that retains all of the characteristic Herzog complexity and nuance, Rescue Dawn is an electrifying action adventure that clamps your nerves with jaws of steel.
# --------------------------------------------------
# Documento 714373: A potentially commercial audience-pleaser that retains all of the characteristic Herzog complexity and nuance, Rescue Dawn is an electrifying action adventure that clamps your nerves with jaws of steel.
# --------------------------------------------------
# Documento 648841: The movie's foolish fantasy comes awfully close to seeming nuts.
# --------------------------------------------------
# Documento 747146: Clark Gable and Burt Lancaster headline a tense WWII submarine adventure as battling officers.
# --------------------------------------------------
# Documento 747147: Clark Gable and Burt Lancaster headline a tense WWII submarine adventure as battling officers.
# --------------------------------------------------
# Documento 222865: A fresh Marvel adventure that stands high above its predecessor and even surpasses "The Avengers" in its technique and execution.
# --------------------------------------------------
# Documento 714385: Extremely well-made Vietnam War-era POW escape adventure is both psychologically and politically bizarre.
# --------------------------------------------------
# Documento 419477: Full of zany subplots that seem to come out of the imagination and innocence of a child. Anyone who ventures out to see this adventure will dig Holes! Incredible entertainment for everyone!
# --------------------------------------------------
# Documento 222870: The Winter Soldier is no labored treatise on political science; it fulfills all the expectations of a Marvel movie. But this time the danger doesn't emanate from a fantasy villain like Neutron or an imaginary realm like Asgard.
# --------------------------------------------------
# Documento 157335: Reality, fantasy and cinema interweave with such grace and power that it's often difficult to separate one from the other, which is, of course, the point.
# --------------------------------------------------
# Documento 550552: Man On a Ledge might look like another preposterous heist thriller, but it's really a topical wish-fulfilment fantasy, in which the common man gets sweet revenge on the unscrupulous wealthy elite.
# --------------------------------------------------
# Documento 419481: The time-tripping subplots are confusing, + the slow-paced middle of this suspenseful, serendipitous coming-of-age adventure begs for judicious editing, but it's an intriguing premise with sly humor and a payoff worth waiting for. Dig it!
# --------------------------------------------------
# Documento 255642: Smug, sanitized fantasy, in which the hysterical blonde attention-seeker, in a succession of sparkly outfits, is uprooted from New York to the boring suburbs and learns boring suburban values like telling the truth.
# --------------------------------------------------
# Documento 26269: Like other WWII adventures, Sahara contains elements of propaganda, but it's expertly directed by Korda, well acted by Bogart and the other men, and strikingly photographed by Rudolph Mate who received an Oscar nomination.
# --------------------------------------------------
# Documento 714397: Extremely well-made Vietnam War-era POW escape adventure is both psychologically and politically bizarre.
# --------------------------------------------------
# Documento 222883: Often has something akin to the tone of a 1970s-era paranoid conspiracy thriller. Marrying the slam-bang adventure of a comic book with something more cerebral was a brilliant idea, one that is very entertainingly executed.
# --------------------------------------------------
# Documento 222888: a super hero adventure grounded in reality that works on both levels, and a genuinely suspenseful story that harks back to the best of the Cold War thrillers
# --------------------------------------------------
# Documento 157360: ...Almodovar's meta-movie teases us with Big Ideas about those of us who love our fantasies so much that we turn them into our realities.
# --------------------------------------------------
# Documento 288438: The Devil's Backbone truly is a masterful film, one rife with both symbolism and story. This is a poetic piece of cinema that manages to expose the horrors of war through the lens of fantasy.
# --------------------------------------------------
# Documento 1042102: What was a rather pedestrian "Twilight Zone" episode may have inspired this nice little fantasy thriller. That makes it well above average for time travel films.
# --------------------------------------------------
# Documento 812729: Could this adventure be as great as jumping Springfield Gorge? Those visits from Sideshow Bob? Ralph choo choo choosing Lisa? Yes. Worst episode ever? No.
# --------------------------------------------------
# Documento 943802: If you love adventurous cinema, [Cristi] Puiu's transcendent, unique foray into the culture of health care is a must-see.
# --------------------------------------------------
# Documento 1042108: Discovering a neighbor's photographic time machine complicates life for three young L.A. flatmates in this clever fantasy thriller.
# --------------------------------------------------
# Documento 517821: After four films and countless adventures, these characters have become a family, and they've become part of ours too.
# --------------------------------------------------
# Documento 714434: Aside from a riveting adventure story that Herzog tells in all of its terrifying, stripped-down simplicity, Rescue Dawn is a fascinating study of human particularity.
# --------------------------------------------------
# Documento 1074889: ...a formula stirring in upscale sex, murder, holiday mutilation and lots of junior high school revenge fantasy.
# --------------------------------------------------
# Documento 222921: There is something for everyone in this big, sprawling adventure film with political commentaries and absurd conspiracies, but there is a lot less comedy than there was in 'Thor: The Dark World,' for instance.
# --------------------------------------------------
# Documento 714445: Aside from a riveting adventure story that Herzog tells in all of its terrifying, stripped-down simplicity, Rescue Dawn is a fascinating study of human particularity.
# --------------------------------------------------
# Documento 550609: One of the longest, dumbest and most savage revenge fantasies extant.
# --------------------------------------------------
# Documento 1009363: This is an amazing-looking film with a couple of how-in-the-world-did-they-do-that scenes. It works as a tale of survival, adventure yarn, revenge saga and spiritual journey.
# --------------------------------------------------
# Documento 911064: If a good children's film is supposed to open the eyes of its young audience, then the somewhat misleadingly titled "Tall Tale: The Unbelievable Adventures of Pecos Bill" is mighty good.
# --------------------------------------------------
# Documento 911066: A good Disney fantasy adventure for kids.
# --------------------------------------------------
# Documento 911072: Excuse me, is this any lesson for kids? Hey, kids, if you dream hard enough, mythical heroes will step out of your fantasies and help defeat your enemies with fancy gunplay.
# --------------------------------------------------
# Documento 911073: This film contains the stereotypical western adventure movie material.
# --------------------------------------------------
# Documento 911075: It's homespun homily time: TALL TALE may look like a rousing adventure story for the whole family, but it's really a vehicle for the kind of tiresome moral aphorisms that only William Bennett could love. . .
# --------------------------------------------------
# Documento 714468: A film that works as a thrilling adventure as exciting and visceral as any put on the screen in recent memory and as an intimate character piece about an ordinary man whose extraordinary courage allows him to persevere against seemingly insurmountable odd
# --------------------------------------------------
# Documento 1009381: Judged on its own merits - as it should be - The Revenant is a thrilling adventure that pits the audience at the heart of a long, painful journey about survival and redemption.
# --------------------------------------------------
# Documento 714473: Herzog makes no attempt to pump this story up into a thrilling adventure. There is nothing thrilling about dysentery, starvation, insect bites and despair.
# --------------------------------------------------
# Documento 321266: On an adventure level, the performances are quite good. The one by Mr. Lee, not only the picture's supermaster killer but a fine actor as well, is downright fascinating.
# --------------------------------------------------
# Documento 714482: A film that works as a thrilling adventure as exciting and visceral as any put on the screen in recent memory and as an intimate character piece about an ordinary man whose extraordinary courage allows him to persevere against seemingly insurmountable odd
# --------------------------------------------------
# Documento 812786: Could this adventure be as great as jumping Springfield Gorge? Those visits from Sideshow Bob? Ralph choo choo choosing Lisa? Yes. Worst episode ever? No.
# --------------------------------------------------
# Documento 222967: Satisfying as a standalone adventure without sacrificing continuity ...
# --------------------------------------------------
# Documento 714487: Herzog makes no attempt to pump this story up into a thrilling adventure. There is nothing thrilling about dysentery, starvation, insect bites and despair.
# --------------------------------------------------
# Documento 1009408: An adventure for all the senses that is only posible due to the poetic and refined technical work. [Full review in Spanish]
# --------------------------------------------------
# Documento 190211: For fans of Barrymore and Sandler's previous cinematic encounters, this latest effort isn't up to snuff, losing the sweetness and friendly playfulness that elevated their past screen adventures.
# --------------------------------------------------
# Documento 1009414: The result is a gripping blend of psychological drama and epic adventure, brutal and bloody but underpinned with a delicate lyricism. Barely saying a word, DiCaprio is extraordinary.
# --------------------------------------------------
# Documento 1009442: The Revenant was enough to be the great adventure movie it is, but its director always wants more. [Full Review in Spanish]
# --------------------------------------------------
# Documento 452387: Domestic chaos is delicately handled, in this feature debut by Maya Forbes, whose childhood experiences living with her bi-polar father while her mother studies form a kaleidoscope of tumultuous emotional adventures
# --------------------------------------------------
# Documento 550693: Intentional or not, Man on Fire's over-the-top evocation of Christian retribution goes a long way to making this otherwise standard revenge fantasy watchable.
# --------------------------------------------------
# Documento 26407: Top-notch swashbuckling adventure.
# --------------------------------------------------
# Documento 26411: ...romance, adventure, and intrigue; lavish costumes and sets; heroes and scoundrels aplenty; and Errol Flynn swinging from ship to ship. What more could you ask for?
# --------------------------------------------------
# Documento 124720: Fantasy scenes aside, the film itself is pretty darn impressive on a number of other levels and has a cumulative emotional punch that's quite unexpected.
# --------------------------------------------------
# Documento 26416: I don't feel so much emotion with this adventure film by Curtiz, in his tenth collaboration with the mythical Errol Flynn, but I can instantly recognize, despite the lack of dynamism, that it has some interesting characters. [Full review in Spanish]
# --------------------------------------------------
# Documento 26417: Checks all the boxes for a seafaring adventure epic.
# --------------------------------------------------
# Documento 550722: I couldn't help thinking afterwards how harebrained the whole adventure was. Yet Washington is so charming, so charismatic, and so heroic in his role, he makes the movie.
# --------------------------------------------------
# Documento 124753: It opens at fever pitch and then starts soaring -- into genetic fantasy, into a precognitive dream of delirium and delight.
# --------------------------------------------------
# Documento 485216: Director Donald Petrie's niche seems to be lighthearted, instantly forgettable romantic fantasies like Miss Congeniality and How To Lose A Guy In 10 Days, and this sweet-natured bit of fluff fits right in.
# --------------------------------------------------
# Documento 92006: The set-up's better than OK, but the black comedy premise never develops into anything remotely interesting. The piece staggers along like a third-rate fringe play, with increasingly pointless fantasy sequences.
# --------------------------------------------------
# Documento 616295: It is at once a cool romance and a cool comedy, a hot thriller and a hot adventure.
# --------------------------------------------------
# Documento 550762: Context is crucial for this stranger than fiction docu: It's impossiblle to watch Marsh's exciting chronicle of a unique adventure in the summer of 1974 without thinking of 9/11 and its aftermath.
# --------------------------------------------------
# Documento 386923: A teen and pre-teen adventure tale fondly remembered by everyone I know.
# --------------------------------------------------
# Documento 1009516: This is film-making of the very highest order, brilliantly combining all the heritage and history of the epic adventure picture with the very latest in movie-making technology.
# --------------------------------------------------
# Documento 386929: A contemporary equivalent to the Hardy Boys adventure tales.
# --------------------------------------------------
# Documento 1075058: It shares much in common with producer Irwin Allen's disaster pics of the 1970s (The Swarm; Beyond The Poseidon Adventure), which also featured a lot of stars in really bad films.
# --------------------------------------------------
# Documento 386931: A rolicking good time is had by all in this adventure that is built on archetypal plot strands that tie together oh so well.
# --------------------------------------------------
# Documento 714612: What we miss is the real Herzogian touch that can translate tales of derringdo into something more than mere adventure and stir the soul as well as the heart and mind.
# --------------------------------------------------
# Documento 386933: The Goonies is a smooth mixture of the usual ingredients from Steven Spielberg action movies, made special because of the high-energy performances of the kids who have the adventures.
# --------------------------------------------------
# Documento 714613: An effective, unassuming and old-fashioned action adventure which is - perhaps a little faute de mieux - probably the best film of the week.
# --------------------------------------------------
# Documento 485244: sheer bubblegummy fantasy, designed to appeal to young women who daydream about starring in their own versions of 'Sex and the City.' ...It's also the sort of film that Lohan has now outgrown.
# --------------------------------------------------
# Documento 714622: What we miss is the real Herzogian touch that can translate tales of derringdo into something more than mere adventure and stir the soul as well as the heart and mind.
# --------------------------------------------------
# Documento 714623: An effective, unassuming and old-fashioned action adventure which is - perhaps a little faute de mieux - probably the best film of the week.
# --------------------------------------------------
# Documento 616322: A diverting adventure, but in truth, a little precious... Not my favorite of Hitch's later films.
# --------------------------------------------------
# Documento 386950: An excellent child oriented fantasy adventure in the vein of "The Hardy Boys."
# --------------------------------------------------
# Documento 616327: Thrilling, funny, and romantic; it elevates popcorn adventure to art...defines the ideal use of star power....[and] marries deadly intrigue to out-and-out delight. [Blu-ray]
# --------------------------------------------------
# Documento 92042: ...an exploration of the meaning of love amidst a lot of macho posturing that features a great cast and great dialogue undone by staginess, clunky fantasy elements and a weak conclusion.
# --------------------------------------------------
# Documento 714646: Bale's lack of ambiguity points to the biggest limitation of a film that makes the grade as an adventure yarn by ignoring the most disturbing implications of its story.
# --------------------------------------------------
# Documento 714647: Bale's lack of ambiguity points to the biggest limitation of a film that makes the grade as an adventure yarn by ignoring the most disturbing implications of its story.
# --------------------------------------------------
# Documento 386968: In many ways, the film resembles a younger take on the adventures of Indiana Jones.
# --------------------------------------------------
# Documento 92060: It boasts a crackerjack cast and a richly dense script, and scenes of inspired fantasy and hallucinatory nightmarish power.
# --------------------------------------------------
# Documento 485280: A totally predictable and competently made feelgood fantasy flick for females under 30. If you want an escape and rest your brain, try your luck
# --------------------------------------------------
# Documento 550819: Man On Wire is surprising and entertaining, an unexpected adventure story for the modern world.
# --------------------------------------------------
# Documento 714670: Animated adventure doesn't get more rousing than this.
# --------------------------------------------------
# Documento 485296: This movie is less about the two main characters falling in love and more about exploring the equilibrium of good will in the universe. It's a mystical fantasy about how each decision we make matters and the differing paths life can take.
# --------------------------------------------------
# Documento 452529: After some indulgent side trips (Grindhouse, Deathproof), Quentin Tarantino is back to form with this World War II fantasy fiasco. It's mad, it's bad and it's thoroughly entertaining, with some of the most disciplined storytelling Tarantino has produced.
# --------------------------------------------------
# Documento 616368: Action, adventure, and romance - like something out of a James Bond episode - collide to create one of the most exciting and memorable films ever made.
# --------------------------------------------------
# Documento 714673: Animated adventure doesn't get more rousing than this.
# --------------------------------------------------
# Documento 223158: Captain Fantastic" uses bleak but gentle comedy to pinpoint the variety of ways we wrestle with grief, but the film undermines Mortensen's performance and its own thematic ambitions by presenting the character as an idealized fantasy figure.
# --------------------------------------------------
# Documento 26552: It not only marked the return of Fred MacMurray to comedy -- in which he got his start in the 1930s--but it also convinced the Disney folks that the combination of situation comedy and fantasy was an idea worth pursuing.
# --------------------------------------------------
# Documento 354235: Screenwriter Gerald Di Pegoto...[is] like a child caught in a fib, trying to wriggle out of his predicament by cooking up ever more extravagant fantasies.
# --------------------------------------------------
# Documento 26561: The problem with routine crime and law enforcement fantasies of this kind is that their vague stabs at authenticity are completely subverted by action sequences that belong in Road Runner cartoons.
# --------------------------------------------------
# Documento 452547: Be prepared for unsettling shifts in pace and tone, be prepared to be shocked and amused, to laugh and guffaw and to be always surprised in this comic fantasy which is cheeky enough to reinvent history and has audiences clapping as it does so
# --------------------------------------------------
# Documento 452551: Energetic, inventive, swaggering fun, Quentin Tarantino's Inglourious Basterds is a consummate Hollywood entertainment -- rich in fantasy and blithely amoral.
# --------------------------------------------------
# Documento 387019: Goosebumps is chock full of fun moments whether they're all logical or not, and it's an adventure that should appeal to both young viewers new the series and older readers who devoured them as kids.
# --------------------------------------------------
# Documento 452556: [A] bleakly comic revenge fantasy... [that] is, hilariously, all about acknowledging the power of cinema: have your revenge, but have it on film...
# --------------------------------------------------
# Documento 157645: The film is both a police thriller and a drug addled fantasy with an iguana for a guide and Cage plays it like Hunter S. Thompson with a badge.
# --------------------------------------------------
# Documento 321487: The overarching mood is self-congratulation, which no doubt helps the sugary medicine of lifestyle fantasy go down.
# --------------------------------------------------
# Documento 1107922: Social realism dissipates into a fantasy lifted by Jessie Buckley's charisma...bursting with a force that outshines a familiar story, puts across any country song with verve
# --------------------------------------------------
# Documento 124885: The off-putting CGI Chipmunks coast through a derivative, squeaky-voiced adventure with fleeting moments of charm.
# --------------------------------------------------
# Documento 387032: Goosebumps is a fun, if frantic, scary adventure for kids that even captures the spirit of R.L. Stine's original books.
# --------------------------------------------------
# Documento 944090: Intense animated adventure filled with brutality, deaths.
# --------------------------------------------------
# Documento 1042396: This sappy romantic fantasy proves that a movie doesn't have to be a CGI extravaganza based on a video game, comic book or toy line to be inordinately dumb.
# --------------------------------------------------
# Documento 124894: Delivers precisely what is expected to its fans...The super-high quality of the animation, which places Alvin, Theodore and Simon in the real world, remains a real highlight in these innocuous adventures - it really is an unrecognised art.
# --------------------------------------------------
# Documento 1042399: The book is richer, but this is a solid, endearing telling of the same essential story, and is well worth the price of admission for those who appreciate romantic fantasy.
# --------------------------------------------------
# Documento 26598: Very entertaining sci-fi drama about the adventures of an escaped robot on the loose.
# --------------------------------------------------
# Documento 944103: As epic of a story as it is, it also whets the appetite for smaller-scale, Superman-specific adventures.
# --------------------------------------------------
# Documento 1040837: Marrying American voices to Belgian animation, this candy-colored adventure has a harum-scarum energy that rarely flags.
# --------------------------------------------------
# Documento 321513: In 2015, however, bros only come before hos alphabetically, and what once felt like an innocent tale of wish fulfillment now plays like the masturbatory fantasy of a men's-rights activist.
# --------------------------------------------------
# Documento 255978: A splendid example of a genre no longer much in fashion, the jungle adventure story.
# --------------------------------------------------
# Documento 124908: Alvin and the Chipmunks: The Road Chip is the fourth, agonising instalment in the franchise that charts the adventures of three enormously-punchable helium-voiced rodents.
# --------------------------------------------------
# Documento 255980: The least interesting adventure ever filmed.
# --------------------------------------------------
# Documento 387052: Goosebumps is a great combination of adventure and comedy, it's entertaining and pleases everyone who watches it, regardless if you're familiar with the books or tv series. [Full review in Spanish]
# --------------------------------------------------
# Documento 223216: Despite a brave and edgy performance by Viggo Mortensen and some shining moments of sharp comedy and true emotion, writer-director Matt Ross' hippie fantasy Captain Fantastic suffers from terminal self-satisfaction.
# --------------------------------------------------
# Documento 255990: A lighthearted, good old-fashioned jungle adventure.
# --------------------------------------------------
# Documento 452599: Quentin Tarantino's extremely witty revenge fantasy Inglourious Basterds may be the most fun you'll have at the movies this summer.
# --------------------------------------------------
# Documento 387062: A fun horror adventure for the fans, that will also appeal to newcomers of Stine and the "Goosebumps" novels.
# --------------------------------------------------
# Documento 124921: A rousing adventure story, a romantic comedy, and an affecting afterlife fantasy.
# --------------------------------------------------
# Documento 1042426: Suspend your disbelief and you might find The Time Traveler's Wife a charming if mildly depressing fantasy. Or you might, as I did, travel elsewhere during it. Either way, at least it's a picturesque journey.
# --------------------------------------------------
# Documento 255993: Not bad adventure, nothing special, but not bad
# --------------------------------------------------
# Documento 255994: Ineptly written, feebly acted, clumsily directed yawner of an adventure yarn.
# --------------------------------------------------
# Documento 452605: Tarantino's wartime fantasies may leave history in the dust, but his movie is a surprisingly satisfying contribution to movies about the Holocaust.
# --------------------------------------------------
# Documento 387063: Healthy and light entertainment come from this nice plot where Jack Black is our guide in a family adventure. [Full review in Spanish]
# --------------------------------------------------
# Documento 1075198: Valerian and the City of a Thousand Planets is stunning visually. It never reaches the point of rousing sci-fi adventure, but makes an all out effort to get there.
# --------------------------------------------------
# Documento 419840: If all late-life male fantasies were as entertaining as Hollywood Ending frequently is -- well, we'd all have more fun at the multiplexes.
# --------------------------------------------------
# Documento 387073: Fabulously entertaining and funny action fantasy with monsters running amok as they escape from the locked Goosebumps manuscripts of author R.L Stine (Jack Black)...Huge fun.
# --------------------------------------------------
# Documento 452609: Many Tarantino movies are female revenge fantasies, in which strong women plot the deaths of men who wronged them. In Shosanna and Bridget, the writer-director has fashioned two of his steeliest, most principled femmes fatales.
# --------------------------------------------------
# Documento 1107972: Rose-Lynn's oblivious self-absorption is wearying at times. Still, the movie often entertains with cheeky attitude, occasional flights of musical fantasy and droll dialogue
# --------------------------------------------------
# Documento 256005: Not the worst adventure flick that I've ever seen, but far from a great one either.
# --------------------------------------------------
# Documento 256006: Revel in the sheer insanity and unique humor of this cracking jungle adventure.
# --------------------------------------------------
# Documento 256008: A second-rate jungle adventure that delivers far less than it promises.
# --------------------------------------------------
# Documento 976905: Imagine "Harold and Kumar Go to North Korea," or "Bill and Ted's Excellent North Korean Adventure" or even "The Road to Pyongyang" starring Bob Hope and Bing Crosby. You get the idea.
# --------------------------------------------------
# Documento 387082: This teen horror fantasy (based on RL Stine's bestselling children's books) is made with an anarchic glee that, in its better moments, rekindles memories of Joe Dante's zany, tongue-in-cheek movies of the 1980s.
# --------------------------------------------------
# Documento 124940: Sentimental '80s romantic adventure has mild cursing.
# --------------------------------------------------
# Documento 1075212: An expansive, expensive adventure whose creativity outweighs its more uneven elements.
# --------------------------------------------------
# Documento 256014: The lackluster adventure film misses out on most of the thrills from the Michael Crichton 1980 bestseller.
# --------------------------------------------------
# Documento 682001: The film too, for all its embrace of over-the-top gore, death by reanimated figurines and violent fantasy, is reflecting the issues of our times.
# --------------------------------------------------
# Documento 682002: The film too, for all its embrace of over-the-top gore, death by reanimated figurines and violent fantasy, is reflecting the issues of our times.
# --------------------------------------------------
# Documento 387089: A pacy, quirky and thoroughly entertaining family adventure.
# --------------------------------------------------
# Documento 1075229: Valerian is funny, gorgeous, and full of the type of mindbending scenarios that remind you of what fantasies are for.
# --------------------------------------------------
# Documento 1042464: The film version of the novel will drive you potty if you try to make any sense of it. Just surrender to a far-fetched fantasy and the reward is a lush, high-gloss weepie.
# --------------------------------------------------
# Documento 976931: a silly, broad, very funny comedy about a couple of close male friends who represented high and low, going on a profoundly stupid adventure.
# --------------------------------------------------
# Documento 387108: Goosebumps feels like a tongue-in-cheek kids action adventure from the 80s -- such as Gremlins or The Goonies -- and deserves to sit beside them in the genre.
# --------------------------------------------------
# Documento 485412: Queen Latifah shines as an avid New Jersey Nets fan and an accomplished physical therapist who opens herself up to love and true adventure.
# --------------------------------------------------
# Documento 1075237: A bracing, unique, vivacious, visually glorious sci-fi adventure that gleefully vibrates with impish life... It's the best science fiction film of the year,
# --------------------------------------------------
# Documento 1075246: A visually dazzling, grin-inducing space adventure.
# --------------------------------------------------
# Documento 616497: Contrived fantasy. Only in Hollywood could Harrelson get Theron's nemesis to recant his inadmissably irrelevant tale on the stand with such meager questioning.
# --------------------------------------------------
# Documento 452661: I don't know if I've ever seen a revenge fantasy so willfully messed up, sometimes offensively so, that still manages to be worthwhile for whole sections of its 2 1/2 hours. The opening is as good a sequence as Tarantino has ever created.
# --------------------------------------------------
# Documento 1075262: Besson creates wondrous creatures and settings, dropping viewers into a far-future adventure teeming with alien life. If only he'd left out the humans.
# --------------------------------------------------
# Documento 387135: Filled with fun, fantasy, ghosts, and ghouls, Goosebumps 2: Haunted Halloween will bring smiles to your face and delight audiences from the youngest R.L. Stine fan to the oldest.
# --------------------------------------------------
# Documento 1075265: Besson's commercial instincts for sleek, violent fantasy are often sound, but "Valerian" is more sedative than show.
# --------------------------------------------------
# Documento 649285: Roeg's debut as a director is a virtuoso juggling act which manipulates its visual and verbal imagery so cunningly that the borderline between reality and fantasy is gradually eliminated.
# --------------------------------------------------
# Documento 1009734: In theory, it's a promising take on a genre that is pretty much fantasy fulfillment. In practice, however, it's quite another thing.
# --------------------------------------------------
# Documento 485450: Some of us would rather watch Dwight Howard act like Common can lead the Nets to a title. At least that fantasy isn't insulting.
# --------------------------------------------------
# Documento 1075276: Besson ... stuffs us to the breaking point with this psychedelic space fantasy. I enjoyed the feast, too, although I found it more junk food pig-out than fine-dining experience.
# --------------------------------------------------
# Documento 1042510: Sure to hit the spot for anyone with an appetite for sweet, unselfconscious romantic fantasy.
# --------------------------------------------------
# Documento 649294: It's not so much a linear story of one man's adventures as an enquiry into the nature of performance, gender and the very structure of society.
# --------------------------------------------------
# Documento 1042513: I kept doing what every fantasy should never allow one to do--question it every step of the way.
# --------------------------------------------------
# Documento 223317: [It] shines as a sort of wish-fulfillment fantasy for a certain outdoors-oriented mind set, which almost makes up for its over-the-top moments and underwritten characters.
# --------------------------------------------------
# Documento 321622: A vapid male fantasy scantily clad as a movie, this macho soap-opera is all about cocks and gawks. A fantasy-lifestyle-league Super Bore for Hollywood's coveted male-20-something demographic, all bloated up for the big screen.
# --------------------------------------------------
# Documento 485461: The New Jersey Nets reach the NBA conference finals in Just Wright, so it goes without saying the movie is a ludicrous fantasy.
# --------------------------------------------------
# Documento 944216: Think of it as The Grey (2011) without the wolves, or as a boy's own adventure with all the adventure stripped away... a film which, much like its unassuming protagonist, conceals the extraordinary deep within the ordinary.
# --------------------------------------------------
# Documento 1075289: An utter delight and one of the most gorgeous fantasies to hit the screen in recent memory-the kind of film that can take moviegoers logy from the usual array of craptaculars and render them absolutely giddy with its pure fun.
# --------------------------------------------------
# Documento 321631: Entourage is the male fantasy of anyone who's ever dreamed of conquering Hollywood. [Full review in Spanish]
# --------------------------------------------------
# Documento 452705: ...an old-fashioned World War II movie showing war as fun adventure updated by graphic violence, abetted by Tarantino's chimerical speculation.
# --------------------------------------------------
# Documento 452706: It's a lurid, wide-screen fantasy of how things might have gone if Sergio Leone or Sam Fuller had called the shots.
# --------------------------------------------------
# Documento 780387: Serendipity plays with the fantasy of fate and destiny and romantic kismet with all the lightness and frivolity of a championship chess match.
# --------------------------------------------------
# Documento 26727: It's a lush but humorless adventure tale about the mythical mariner and storyteller.
# --------------------------------------------------
# Documento 354408: ...not a wishful paean to a fantasy version of America, but a portrait of America - its awfulness and beauty, promise and pain - as seen through the eyes of an innocent.
# --------------------------------------------------
# ...
# --------------------------------------------------
# Documento 294796: In its sledgehammer metaphoring and scrappy, eager-to-please charm, it's easy to warm to this latest fantasy teen adaptation.
# --------------------------------------------------
# Documento 98188: Frivolous stuff, but there's a sour edge to the silliness, with far more gay panic colouring the jokes than you'd expect from the director of 'The Adventures of Priscilla, Queen of the Desert.'
# --------------------------------------------------
# Documento 98190: Director Stephan Elliott made The Adventures of Priscilla, Queen of the Desert but here he doesn't seem to know his farce from his elbow.
# --------------------------------------------------
# Documento 163727: The film looks great and there some striking set-pieces, but in spite of a series of comic quips -- the new film lacks a sense of adventure and fun. Nevertheless, Nolan, Goyer and Bale have still managed to revitalize the ailing franchise.
# --------------------------------------------------
# Documento 294800: For a tale that trumpets the virtues of non-conformity, teen fantasy adventure Divergent proves disappointingly content to follow the pack.
# --------------------------------------------------
# Documento 294798: Totalitarianism versus the individual is the basic concept of Divergent, a thrilling sci-fi adventure that is every bit as good as The Hunger Games with a dash of The Matrix added for good measure
# --------------------------------------------------
# Documento 393102: An odd and attractive adventure, with a notable ability to to fictionalize at the same time that it's concerned with historical reconstruction. [Full Review in Spanish]
# --------------------------------------------------
# Documento 655250: Perhaps on Jack's next adventure he could sail to the end of the world to locate a more judicious editor.
# --------------------------------------------------
# Documento 753555: So mediocre that future adventures seem far from likely.
# --------------------------------------------------
# Documento 851857: It's not as quintessential as Spider-Man 2 or as imaginative as Into the Spider-Verse, but it makes a strong case for itself as the most fun Spidey adventure yet.
# --------------------------------------------------
# Documento 130966: A cleverly-comedic, high-concept adventure, artfully-executed, and thought-provoking, too!
# --------------------------------------------------
# Documento 851865: Spider-Man may be far away from NYC in this adventure, but never has his story hit closer to home.
# --------------------------------------------------
# Documento 655258: The entertainment life raft to be found in these waters is the aura of mystery and adventure provided by a masterful technical crew.
# --------------------------------------------------
# Documento 556956: Introducing children to fun questions about evolution and gender politics, Mars Needs Moms is an odd, little hybrid of adventure and simplistic allegory.
# --------------------------------------------------
# Documento 655261: The most visually spectacular, action-packed and surreal of the adventures of Capt. Jack Sparrow.
# --------------------------------------------------
# Documento 294814: No, it's not wildly different than other science fiction, hero's journey, and adventure movies. Sometimes we call such stories archetypal. Mythic, even.
# --------------------------------------------------
# Documento 851870: Not only is "Spider-Man: Far From Home" a great Spidey adventure, one that ties into the past and future of the MCU, it's also another tremendous high school story. Loved it.
# --------------------------------------------------
# Documento 1081248: Registers as another high-flying James Bond adventure story.
# --------------------------------------------------
# Documento 556964: Succeeds both as a sci-fi adventure and as a familial love story.
# --------------------------------------------------
# Documento 950181: A down and dirty action adventure, and the best escapist entertainment around. Check your brain at the door for non-stop rowdy, riotous and raucous fun.
# --------------------------------------------------
# Documento 753576: So mediocre that future adventures seem far from likely.
# --------------------------------------------------
# Documento 1048500: Beautifully shot thriller that gains points for sheer star power but ultimately delivers very little in terms of action, adventure or romance.
# --------------------------------------------------
# Documento 294838: [Divergent] does a lot right, with slick visuals, an interesting premise and top cast delivering moments when this fantasy thriller is just that, thrilling, although it's hard to shake the impression this is a second-rate Hunger Games.
# --------------------------------------------------
# Documento 327606: It's a place where man's social retardation and his sexual fantasies collide.
# --------------------------------------------------
# Documento 98230: Despite its flaws, A Field in England is an original, adventurous, imaginative, compelling work, a rare enough thing in a British cinema stifled by formulaic scripts and timorous financing entities, to deserve being celebrated.
# --------------------------------------------------
# Documento 294843: An intriguing premise, sharp casting and thoughtful world-building make "Divergent" an engrossing science-fiction adventure.
# --------------------------------------------------
# Documento 556987: A fun, all-ages space adventure.
# --------------------------------------------------
# Documento 655293: For horror, suspense and dark fantasy fans wondering about the monstrous Davy Jones, the legendary Kracken, and phantomly pirates - they're all here, but the story is really more about the end of an era.
# --------------------------------------------------
# Documento 556990: Surprisingly touching adventure has sad moments amid comedy.
# --------------------------------------------------
# Documento 851899: It's not as quintessential as Spider-Man 2 or as imaginative as Into the Spider-Verse, but it makes a strong case for itself as the most fun Spidey adventure yet.
# --------------------------------------------------
# Documento 1081280: While it doesn't reach its full potential, Roger Moore's final 007 outing is still a largely entertaining if admittedly flawed adventure.
# --------------------------------------------------
# Documento 851907: Spider-Man may be far away from NYC in this adventure, but never has his story hit closer to home.
# --------------------------------------------------
# Documento 131012: Will appeal primarily to those who like their armchair adventures picture-postcard pristine and sprinkled with touches of proud self-sufficiency.
# --------------------------------------------------
# Documento 688068: Remarkable for its excellent storytelling, its economical, compressed characterisations and for its profound humanity, it's an adventure story and history lesson all in one.
# --------------------------------------------------
# Documento 655302: [Erupts] into a grand and glorious adventure at the final hour. After lying dead in the water during much of its three-part odyssey, Pirates of the Caribbean has saved the best for last. The third time is the charmer.
# --------------------------------------------------
# Documento 655303: In terms of pure adventure, there's less of it here than in Pirates 2 -- the action doesn't really start until about two hours in, and even then it's hard to understand the shifting allegiances or make sense of why the different sides are fighting.
# --------------------------------------------------
# Documento 688069: Remarkable for its excellent storytelling, its economical, compressed characterisations and for its profound humanity, it's an adventure story and history lesson all in one.
# --------------------------------------------------
# Documento 851912: Not only is "Spider-Man: Far From Home" a great Spidey adventure, one that ties into the past and future of the MCU, it's also another tremendous high school story. Loved it.
# --------------------------------------------------
# Documento 688074: A movie of adventure, courage and spirit, revealing the best and worst in human nature and introducing terrific new talent.
# --------------------------------------------------
# Documento 688075: A movie of adventure, courage and spirit, revealing the best and worst in human nature and introducing terrific new talent.
# --------------------------------------------------
# Documento 262095: A rare teen film that spends less time pandering to wish-fulfilling fantasies than baring honest interpersonal realities.
# --------------------------------------------------
# Documento 655313: I like my action movies complicated, but At World's End is less a complexity than it is a high seas bazaar with everyone and everything vying for attention. You end up going home with nothing to show for your adventure.
# --------------------------------------------------
# Documento 1081300: This fantastically wooden and dodgily acted British Viking fantasy appears to be the result of its creators binge-watching Games of Thrones, although the battle scenes here are about as thunderous as a sparrow's fart.
# --------------------------------------------------
# Documento 32726: A bubble-gum swashbuckling adventure, rapidly fading in the cultural rear-view mirror. Still, it goes down easy, and Tim Curry makes a good bad guy.
# --------------------------------------------------
# Documento 557014: Don't be put off by the title. Wells harnesses 3D mo-cap wizardry for a children's adventure that balances storytelling and sci-fi.
# --------------------------------------------------
# Documento 32729: A fun adventure, but nothing new. Average retelling of the legend. Platt steals the show.
# --------------------------------------------------
# Documento 65498: Lacking any dramatic credibility or historical authenticity, Shepard's thriller about the Bosnian wars is a silly, presposterous fantasy that can't decide whether it's about journalism, politics, male camaraderie, or coming-of-age.
# --------------------------------------------------
# Documento 557018: An uninvolving mo-cap adventure that's well below par. Marvin the Martian would be unhappy to share his planet with this bunch.
# --------------------------------------------------
# Documento 1081311: This cheerfully silly action fantasy is unpretentious fun best suited to younger viewers.
# --------------------------------------------------
# Documento 32736: Conceived frankly as a product, complete with hit-to-be theme song over the closing credits, this adventure film cares less about storytelling than about keeping the Musketeers' feathered hats on straight whenever they go galloping.
# --------------------------------------------------
# Documento 1081313: Frequent battle violence abounds in trite medieval fantasy.
# --------------------------------------------------
# Documento 65504: A dismal misfire that attempts to make black comedy out of the adventures of war correspondents and the dirty business of international politics.
# --------------------------------------------------
# Documento 32740: Those who have never seen a previous "Musketeers" adaptation or a truly exciting Hollywood adventure in the grand style may be swept along, but the mechanical, paint-by-numbers feel of this outing is too evident to ignore.
# --------------------------------------------------
# Documento 1081316: Highly entertaining and slightly camp historical adventure full of great stunts, larger-than-life characters and splendidly OTT dialogue.
# --------------------------------------------------
# Documento 557030: Motion-capture animation takes a giant step backwards with this unappealing outer-space adventure.
# --------------------------------------------------
# Documento 524263: Here's a globe-trotting boy-on-his-own adventure, a narrative of scrappy survival and familial love and many teary reconciliations, tracing the outlines of Brierley's life in a busy two hours.
# --------------------------------------------------
# Documento 32744: . Her crazy adventure teaches Alice about change, the multiple uses of words, curiosity, nonsense, and the great mysteries of life
# --------------------------------------------------
# Documento 851945: Far From Home has all the right stuff to not just be another thrilling Spider-Man adventure, but a bold step forward for the future of both the hero and his world.
# --------------------------------------------------
# Documento 1015789: An early confirmation that we are seeing the birth of an authentic filmic author in an unusual field in Mexican cinema: fantasy films. [Full review in Spanish]
# --------------------------------------------------
# Documento 196589: Movie magic aplenty in animated action adventure from Disney.
# --------------------------------------------------
# Documento 557039: What really sells this fabulous, kid-friendly 3D adventure to anybody over eight (no offense, kids) is its astonishing visuals, which uses motion-capture technology to a degree that surpasses what we saw in Avatar.
# --------------------------------------------------
# Documento 688112: A wonderful spiritual adventure story about the arduous trek of three Aboriginal girls in Australia, this is one of the best films of the year!
# --------------------------------------------------
# Documento 1015793: a surreal assimilation of reality to fantasy, wearing its generic influences (sci-fi, noir, horror, pulp) on its face, while also weaving them into the very fabric of it story. It may be concerned with copying, but The Similars is a true original.
# --------------------------------------------------
# Documento 688114: A wonderful spiritual adventure story about the arduous trek of three Aboriginal girls in Australia, this is one of the best films of the year!
# --------------------------------------------------
# Documento 655347: Despite its length and failure to sell a love story, I mostly enjoyed this buoyant surreal adventure.
# --------------------------------------------------
# Documento 32756: Strictly for Martin & Lewis fans - another way of saying "not for me, thanks" - this latest of the zany partners' adventures takes them to a haunted island near Cuba.
# --------------------------------------------------
# Documento 851952: The emphasis is clearly on having fun, as the laughs fly as thick and fast as some of Spidey's webs, providing a crowd-pleasing adventure that only really delivers its biggest emotional hits late on.
# --------------------------------------------------
# Documento 950256: ... a perfectly enjoyable mercenaries-on-a-mission-of-redemption adventure with a mix of testosterone-fueled camaraderie and this-time-it's-personal seriousness.
# --------------------------------------------------
# Documento 1081328: An enjoyable adventure film that benefits from first class work all round, The Vikings is a must for film historians and a pleasure for the rest of us.
# --------------------------------------------------
# Documento 622584: There's very scant plot here; rather, it feels like a sort of escapist fantasy for celebrities in the big city who get tired of all the people surrounding them.
# --------------------------------------------------
# Documento 557049: a disposable family adventure it more than fits the bill
# --------------------------------------------------
# Documento 1081332: [T]remendously exciting, if gory, adventure epic...
# --------------------------------------------------
# Documento 262139: There is nothing new in this teen fantasy.
# --------------------------------------------------
# Documento 1081334: Proper Hollywood overblown Viking adventure with not a shred of authentic detail but lots of glam and ham.
# --------------------------------------------------
# Documento 196605: Funny and engaging 3D adventures of a canine TV star lost in the real world. Disney marketing might ensures a major holiday family hit.
# --------------------------------------------------

# %%
#Cargar el archivo CSV del corpus Rotten Tomatoes movies
corpus_path = 'rotten_tomatoes_movies.csv'
movies_df = pd.read_csv(corpus_path)

#Verificar las primeras filas del DataFrame
print(movies_df.head())
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
#                                    critics_consensus content_rating  \
# 0  Though it may seem like just another Harry Pot...             PG
# 1  Nicole Holofcener's newest might seem slight i...              R
# 2  Blake Edwards' bawdy comedy may not score a pe...              R
# 3  Sidney Lumet's feature debut is a superbly wri...             NR
# 4  One of Disney's finest live-action adventures,...              G
#
#                                               genres          directors  \
# 0  Action & Adventure, Comedy, Drama, Science Fic...     Chris Columbus
# 1                                             Comedy  Nicole Holofcener
# 2                                    Comedy, Romance      Blake Edwards
# 3                                    Classics, Drama       Sidney Lumet
# 4           Action & Adventure, Drama, Kids & Family  Richard Fleischer
#
#                                       authors  \
# 0  Craig Titley, Chris Columbus, Rick Riordan
# 1                           Nicole Holofcener
# 2                               Blake Edwards
# 3                               Reginald Rose
# 4                                 Earl Felton
#
#                                               actors original_release_date  \
# 0  Logan Lerman, Brandon T. Jackson, Alexandra Da...            2010-02-12
# 1  Catherine Keener, Amanda Peet, Oliver Platt, R...            2010-04-30
# 2  Dudley Moore, Bo Derek, Julie Andrews, Robert ...            1979-10-05
# 3  Martin Balsam, John Fiedler, Lee J. Cobb, E.G....            1957-04-13
# 4  James Mason, Kirk Douglas, Paul Lukas, Peter L...            1954-01-01
#
#    ...      production_company  tomatometer_status tomatometer_rating  \
# 0  ...        20th Century Fox              Rotten               49.0
# 1  ...  Sony Pictures Classics     Certified-Fresh               87.0
# 2  ...             Waner Bros.               Fresh               67.0
# 3  ...    Criterion Collection     Certified-Fresh              100.0
# 4  ...                  Disney               Fresh               89.0
#
#   tomatometer_count  audience_status  audience_rating audience_count  \
# 0             149.0          Spilled             53.0       254421.0
# 1             142.0          Upright             64.0        11574.0
# 2              24.0          Spilled             53.0        14684.0
# 3              54.0          Upright             97.0       105386.0
# 4              27.0          Upright             74.0        68918.0
#
#    tomatometer_top_critics_count  tomatometer_fresh_critics_count  \
# 0                             43                               73
# 1                             44                              123
# 2                              2                               16
# 3                              6                               54
# 4                              5                               24
#
#    tomatometer_rotten_critics_count
# 0                                76
# 1                                19
# 2                                 8
# 3                                 0
# 4                                 3
#
# [5 rows x 22 columns]

# %%
# Función de búsqueda y comparación
def search_and_compare_movies(query, inverted_index, df, movies_df, text_column, movie_column, rating_column):
    # Preprocesar la consulta
    query_tokens = preprocess_text(query)
    print(f"Términos de búsqueda (preprocesados): {query_tokens}")

    # Recuperar índices de documentos que contienen los términos
    matching_docs = set()
    for token in query_tokens:
        if token in inverted_index:
            matching_docs.update(inverted_index[token])

    # Mostrar documentos encontrados
    if matching_docs:
        print(f"Se encontraron {len(matching_docs)} documentos que coinciden:")
        movie_scores = []
        for doc_id in matching_docs:
            # Recuperar texto y nombre de la película
            movie_name = df[movie_column].iloc[doc_id]
            review_text = df[text_column].iloc[doc_id]
            print(f"Película: {movie_name}")
            print(f"Reseña: {review_text}")
            print("-" * 50)

            # Buscar la película en el nuevo corpus
            movie_data = movies_df[movies_df['rotten_tomatoes_link'] == movie_name]
            if not movie_data.empty:
                score = movie_data[rating_column].iloc[0]
                movie_scores.append((movie_name, score))
            else:
                print(f"Película '{movie_name}' no encontrada en el corpus de películas.")

        # Determinar la mejor película
        if movie_scores:
            best_movie = max(movie_scores, key=lambda x: x[1])
            print(f"La mejor película según '{rating_column}' es: {best_movie[0]} con un puntaje de {best_movie[1]}.")
        else:
            print("No se encontraron datos para comparar las películas en el corpus de películas.")
    else:
        print("No se encontraron documentos para la consulta.")

# Columnas relevantes
text_column = "review_content"
movie_column = "rotten_tomatoes_link"
rating_column = "audience_rating "

# Consulta de ejemplo
query = input("Introduce tu consulta: ")

# Realizar búsqueda con comparación
search_and_compare_movies(query, inverted_index, df, movies_df, text_column, movie_column, rating_column)
# Out:
# Introduce tu consulta: fantasy adventure
# Términos de búsqueda (preprocesados): ['fantasi', 'adventur']
# Se encontraron 14014 documentos que coinciden:
# Película: m/0814255
# Reseña: A fantasy adventure that fuses Greek mythology to contemporary American places and values. Anyone around 15 (give or take a couple of years) will thrill to the visual spectacle
# --------------------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'audience_rating '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-2ff10ce26e89> in <cell line: 51>()
#      49
#      50 # Realizar búsqueda con comparación
# ---> 51 search_and_compare_movies(query, inverted_index, df, movies_df, text_column, movie_column, rating_column)
#
# <ipython-input-52-2ff10ce26e89> in search_and_compare_movies(query, inverted_index, df, movies_df, text_column, movie_column, rating_column)
#      26             movie_data = movies_df[movies_df['rotten_tomatoes_link'] == movie_name]
#      27             if not movie_data.empty:
# ---> 28                 score = movie_data[rating_column].iloc[0]
#      29                 movie_scores.append((movie_name, score))
#      30             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'audience_rating '
